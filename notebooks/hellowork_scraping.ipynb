# %% [markdown]
# # **Scraper les offres d'emploi sur Hellowork**

# %% [markdown]
# ## **1. Introduction**
#
# - Ce notebook vise à scraper les offres d'emploi depuis l'API Hellowork.
#
# - L'objectif est de récupérer un échantillon d'annonces pour analyser et travailler sur les données.

# %% [markdown]
# ## **2. Chargement des bibliothèques nécessaires**

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# ## **3. Configuration et Envoi de la requête API**

# %%
# - Définir l'endpoint principal de l'API Hellowork et de l'user agent pour "contourner la protection"
endpoint = "https://www.hellowork.com/searchoffers/getsearchfacets"
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'

# Définition des mots-clés pour les recherches
mots_cles = ["Data Ingenieur", "Data Engineer", "Data Analyst", "Data Analyste", "Data Scientist"]
all_offres = []

# Boucle sur les mots-clés
for mot_cle in mots_cles:
    page = 1  # Réinitialisation de la page pour chaque mot-clé
    params = {
        "k": mot_cle,  # Mot-clé pour le poste
        "l": "france",  # Localisation : France
        "d": "all",  # Toutes les annonces disponibles
        "p": page
    }
    
    # Boucle pour récupérer toutes les pages pour le mot-clé en cours
    while True:
        response = requests.get(endpoint, params=params, headers={"User-Agent": user_agent})
        
        if response.status_code == 200:
            data = response.json()
            if 'Results' in data and data['Results']:
                all_offres.extend(data['Results'])  # Ajoute les offres récupérées à la liste
                print(f"Page {page} récupérée avec succès pour le mot-clé {mot_cle}.")
                page += 1  # Passe à la page suivante
                params["p"] = page  # Met à jour le # de page
            else:
                print(f"Aucune offre supplémentaire trouvée pour le mot-clé {mot_cle}.")
                break
        else:
            print(f"Erreur lors de la requête à la page {page} pour le mot-clé {mot_cle} : {response.status_code}")
            break 

# Affichage du nombre total d'offres collectées
print(f"Nombre total d'offres collectées : {len(all_offres)}")
# Out:
# Page 1 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 2 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 3 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 4 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 5 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 6 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 7 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 8 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 9 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 10 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 11 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 12 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 13 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 14 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 15 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 16 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 17 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 18 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 19 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 20 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 21 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 22 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 23 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 24 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 25 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 26 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 27 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 28 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 29 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 30 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 31 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 32 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 33 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 34 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 35 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 36 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 37 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 38 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 39 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 40 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 41 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 42 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 43 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 44 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 45 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 46 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 47 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 48 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 49 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 50 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 51 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 52 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 53 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 54 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 55 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 56 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 57 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 58 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 59 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 60 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 61 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 62 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 63 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 64 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 65 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 66 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 67 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 68 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 69 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 70 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 71 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 72 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 73 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 74 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 75 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 76 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 77 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 78 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 79 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 80 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 81 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 82 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 83 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 84 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 85 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 86 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 87 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 88 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 89 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 90 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 91 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 92 récupérée avec succès pour le mot-clé Data Ingenieur.
# Page 93 récupérée avec succès pour le mot-clé Data Ingenieur.
# Aucune offre supplémentaire trouvée pour le mot-clé Data Ingenieur.
# Page 1 récupérée avec succès pour le mot-clé Data Engineer.
# Page 2 récupérée avec succès pour le mot-clé Data Engineer.
# Page 3 récupérée avec succès pour le mot-clé Data Engineer.
# Page 4 récupérée avec succès pour le mot-clé Data Engineer.
# Page 5 récupérée avec succès pour le mot-clé Data Engineer.
# Page 6 récupérée avec succès pour le mot-clé Data Engineer.
# Page 7 récupérée avec succès pour le mot-clé Data Engineer.
# Page 8 récupérée avec succès pour le mot-clé Data Engineer.
# Page 9 récupérée avec succès pour le mot-clé Data Engineer.
# Page 10 récupérée avec succès pour le mot-clé Data Engineer.
# Page 11 récupérée avec succès pour le mot-clé Data Engineer.
# Page 12 récupérée avec succès pour le mot-clé Data Engineer.
# Page 13 récupérée avec succès pour le mot-clé Data Engineer.
# Page 14 récupérée avec succès pour le mot-clé Data Engineer.
# Page 15 récupérée avec succès pour le mot-clé Data Engineer.
# Page 16 récupérée avec succès pour le mot-clé Data Engineer.
# Page 17 récupérée avec succès pour le mot-clé Data Engineer.
# Page 18 récupérée avec succès pour le mot-clé Data Engineer.
# Page 19 récupérée avec succès pour le mot-clé Data Engineer.
# Page 20 récupérée avec succès pour le mot-clé Data Engineer.
# Page 21 récupérée avec succès pour le mot-clé Data Engineer.
# Page 22 récupérée avec succès pour le mot-clé Data Engineer.
# Page 23 récupérée avec succès pour le mot-clé Data Engineer.
# Page 24 récupérée avec succès pour le mot-clé Data Engineer.
# Page 25 récupérée avec succès pour le mot-clé Data Engineer.
# Page 26 récupérée avec succès pour le mot-clé Data Engineer.
# Page 27 récupérée avec succès pour le mot-clé Data Engineer.
# Page 28 récupérée avec succès pour le mot-clé Data Engineer.
# Page 29 récupérée avec succès pour le mot-clé Data Engineer.
# Page 30 récupérée avec succès pour le mot-clé Data Engineer.
# Page 31 récupérée avec succès pour le mot-clé Data Engineer.
# Page 32 récupérée avec succès pour le mot-clé Data Engineer.
# Page 33 récupérée avec succès pour le mot-clé Data Engineer.
# Page 34 récupérée avec succès pour le mot-clé Data Engineer.
# Aucune offre supplémentaire trouvée pour le mot-clé Data Engineer.
# Page 1 récupérée avec succès pour le mot-clé Data Analyst.
# Page 2 récupérée avec succès pour le mot-clé Data Analyst.
# Page 3 récupérée avec succès pour le mot-clé Data Analyst.
# Page 4 récupérée avec succès pour le mot-clé Data Analyst.
# Page 5 récupérée avec succès pour le mot-clé Data Analyst.
# Page 6 récupérée avec succès pour le mot-clé Data Analyst.
# Page 7 récupérée avec succès pour le mot-clé Data Analyst.
# Page 8 récupérée avec succès pour le mot-clé Data Analyst.
# Page 9 récupérée avec succès pour le mot-clé Data Analyst.
# Page 10 récupérée avec succès pour le mot-clé Data Analyst.
# Page 11 récupérée avec succès pour le mot-clé Data Analyst.
# Page 12 récupérée avec succès pour le mot-clé Data Analyst.
# Page 13 récupérée avec succès pour le mot-clé Data Analyst.
# Page 14 récupérée avec succès pour le mot-clé Data Analyst.
# Page 15 récupérée avec succès pour le mot-clé Data Analyst.
# Page 16 récupérée avec succès pour le mot-clé Data Analyst.
# Page 17 récupérée avec succès pour le mot-clé Data Analyst.
# Page 18 récupérée avec succès pour le mot-clé Data Analyst.
# Page 19 récupérée avec succès pour le mot-clé Data Analyst.
# Page 20 récupérée avec succès pour le mot-clé Data Analyst.
# Page 21 récupérée avec succès pour le mot-clé Data Analyst.
# Page 22 récupérée avec succès pour le mot-clé Data Analyst.
# Page 23 récupérée avec succès pour le mot-clé Data Analyst.
# Page 24 récupérée avec succès pour le mot-clé Data Analyst.
# Page 25 récupérée avec succès pour le mot-clé Data Analyst.
# Page 26 récupérée avec succès pour le mot-clé Data Analyst.
# Page 27 récupérée avec succès pour le mot-clé Data Analyst.
# Page 28 récupérée avec succès pour le mot-clé Data Analyst.
# Page 29 récupérée avec succès pour le mot-clé Data Analyst.
# Page 30 récupérée avec succès pour le mot-clé Data Analyst.
# Aucune offre supplémentaire trouvée pour le mot-clé Data Analyst.
# Page 1 récupérée avec succès pour le mot-clé Data Analyste.
# Page 2 récupérée avec succès pour le mot-clé Data Analyste.
# Page 3 récupérée avec succès pour le mot-clé Data Analyste.
# Page 4 récupérée avec succès pour le mot-clé Data Analyste.
# Page 5 récupérée avec succès pour le mot-clé Data Analyste.
# Page 6 récupérée avec succès pour le mot-clé Data Analyste.
# Page 7 récupérée avec succès pour le mot-clé Data Analyste.
# Page 8 récupérée avec succès pour le mot-clé Data Analyste.
# Page 9 récupérée avec succès pour le mot-clé Data Analyste.
# Page 10 récupérée avec succès pour le mot-clé Data Analyste.
# Page 11 récupérée avec succès pour le mot-clé Data Analyste.
# Page 12 récupérée avec succès pour le mot-clé Data Analyste.
# Page 13 récupérée avec succès pour le mot-clé Data Analyste.
# Page 14 récupérée avec succès pour le mot-clé Data Analyste.
# Page 15 récupérée avec succès pour le mot-clé Data Analyste.
# Page 16 récupérée avec succès pour le mot-clé Data Analyste.
# Page 17 récupérée avec succès pour le mot-clé Data Analyste.
# Page 18 récupérée avec succès pour le mot-clé Data Analyste.
# Page 19 récupérée avec succès pour le mot-clé Data Analyste.
# Page 20 récupérée avec succès pour le mot-clé Data Analyste.
# Page 21 récupérée avec succès pour le mot-clé Data Analyste.
# Page 22 récupérée avec succès pour le mot-clé Data Analyste.
# Page 23 récupérée avec succès pour le mot-clé Data Analyste.
# Page 24 récupérée avec succès pour le mot-clé Data Analyste.
# Page 25 récupérée avec succès pour le mot-clé Data Analyste.
# Page 26 récupérée avec succès pour le mot-clé Data Analyste.
# Page 27 récupérée avec succès pour le mot-clé Data Analyste.
# Aucune offre supplémentaire trouvée pour le mot-clé Data Analyste.
# Page 1 récupérée avec succès pour le mot-clé Data Scientist.
# Page 2 récupérée avec succès pour le mot-clé Data Scientist.
# Page 3 récupérée avec succès pour le mot-clé Data Scientist.
# Page 4 récupérée avec succès pour le mot-clé Data Scientist.
# Page 5 récupérée avec succès pour le mot-clé Data Scientist.
# Page 6 récupérée avec succès pour le mot-clé Data Scientist.
# Page 7 récupérée avec succès pour le mot-clé Data Scientist.
# Page 8 récupérée avec succès pour le mot-clé Data Scientist.
# Page 9 récupérée avec succès pour le mot-clé Data Scientist.
# Page 10 récupérée avec succès pour le mot-clé Data Scientist.
# Page 11 récupérée avec succès pour le mot-clé Data Scientist.
# Page 12 récupérée avec succès pour le mot-clé Data Scientist.
# Page 13 récupérée avec succès pour le mot-clé Data Scientist.
# Page 14 récupérée avec succès pour le mot-clé Data Scientist.
# Page 15 récupérée avec succès pour le mot-clé Data Scientist.
# Page 16 récupérée avec succès pour le mot-clé Data Scientist.
# Page 17 récupérée avec succès pour le mot-clé Data Scientist.
# Page 18 récupérée avec succès pour le mot-clé Data Scientist.
# Page 19 récupérée avec succès pour le mot-clé Data Scientist.
# Page 20 récupérée avec succès pour le mot-clé Data Scientist.
# Page 21 récupérée avec succès pour le mot-clé Data Scientist.
# Page 22 récupérée avec succès pour le mot-clé Data Scientist.
# Page 23 récupérée avec succès pour le mot-clé Data Scientist.
# Aucune offre supplémentaire trouvée pour le mot-clé Data Scientist.
# Nombre total d'offres collectées : 6115

# %% [markdown]
# ## **5. Exploration des données**
#
# - Inspection des données brutes retournées par l'API pour identifier les champs pertinents.

# %%
# Transformation des données en dataframe
df_offres = pd.DataFrame(all_offres)

# %%
df_offres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6115 entries, 0 to 6114
# Data columns (total 64 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   AddressGeoloc                  6115 non-null   object
#  1   ContractDurationFromNumber     531 non-null    object
#  2   ContractBeginDate              5 non-null      object
#  3   ContractEndDate                0 non-null      object
#  4   Shift                          5 non-null      float64
#  5   AltCompanyName                 0 non-null      object
#  6   ContractType                   6115 non-null   object
#  7   Telework                       3538 non-null   object
#  8   Criterions                     6115 non-null   object
#  9   Description                    6115 non-null   object
#  10  Domaine                        5919 non-null   object
#  11  HighLights                     6115 non-null   object
#  12  Id                             6115 non-null   object
#  13  IdOrRef                        6115 non-null   object
#  14  IdCategory                     6115 non-null   int64
#  15  IdApplication                  6115 non-null   int64
#  16  LinkedOffers                   6115 non-null   object
#  17  Localisation                   6115 non-null   object
#  18  Localisations                  6115 non-null   object
#  19  OfferPosition                  6115 non-null   int64
#  20  OfferTitle                     6115 non-null   object
#  21  Profile                        4610 non-null   object
#  22  PublishDate                    6115 non-null   object
#  23  RandomId                       6115 non-null   int64
#  24  Ref                            6115 non-null   object
#  25  DisplayedSalary                6115 non-null   object
#  26  SearchSlug                     0 non-null      object
#  27  SkinHeaderPicture              2290 non-null   object
#  28  SkinHeaderPictureFullUrl       2290 non-null   object
#  29  Tags                           0 non-null      object
#  30  SeoTags                        6113 non-null   object
#  31  TypeResponseFront              6115 non-null   int64
#  32  TypeListeOffres                6115 non-null   object
#  33  Variant                        6115 non-null   object
#  34  UrlOffre                       6115 non-null   object
#  35  UrlSlug                        6115 non-null   object
#  36  CompanyId                      6115 non-null   int64
#  37  CompanyLogo                    5997 non-null   object
#  38  CompanyLogoFullUrl             5997 non-null   object
#  39  CompanyName                    6094 non-null   object
#  40  CompanyNameSlug                6115 non-null   object
#  41  IsResponsiveRecruiter          6115 non-null   bool
#  42  IsAnnonceAugmentee             6115 non-null   bool
#  43  IsAnonymous                    6115 non-null   bool
#  44  IsApplicationSecondaire        6115 non-null   bool
#  45  IsClient                       6115 non-null   bool
#  46  IsClientSecondaire             6115 non-null   bool
#  47  IsClientSecondaireNonBoost     6115 non-null   bool
#  48  IsPartenairePrioritaire        6115 non-null   bool
#  49  IsPartenairePremium            6115 non-null   bool
#  50  IsPartenaire                   6115 non-null   bool
#  51  IsPartenaireGroupe             6115 non-null   bool
#  52  IsFulltime                     6115 non-null   bool
#  53  CompanyIsTransparentRecruiter  6115 non-null   bool
#  54  IsLowQuality                   6115 non-null   bool
#  55  IsManagement                   6115 non-null   bool
#  56  IsNonClient                    6115 non-null   bool
#  57  IsPremium                      6115 non-null   bool
#  58  IsSalaryDisplayable            6115 non-null   bool
#  59  ReferencingSummary             0 non-null      object
#  60  ResponseUrl                    5129 non-null   object
#  61  ResponseEmail                  0 non-null      object
#  62  TypeResponse                   6115 non-null   int64
#  63  UrlBookmark                    6115 non-null   object
# dtypes: bool(18), float64(1), int64(7), object(38)
# memory usage: 2.3+ MB

# %%
df_offres.head()
# Out:
#                                        AddressGeoloc  \
# 0  [{'relevance': 0.0, 'matchLevel': 0, 'distance...
# 1  [{'relevance': 0.0, 'matchLevel': 0, 'distance...
# 2  [{'relevance': 0.0, 'matchLevel': 0, 'distance...
# 3  [{'relevance': 0.0, 'matchLevel': 0, 'distance...
# 4  [{'relevance': 0.0, 'matchLevel': 0, 'distance...
#
#   ContractDurationFromNumber ContractBeginDate ContractEndDate  Shift  \
# 0                       None              None            None    NaN
# 1                       None              None            None    NaN
# 2                       None              None            None    NaN
# 3                       None              None            None    NaN
# 4                       None              None            None    NaN
#
#   AltCompanyName ContractType                 Telework  \
# 0           None          CDI      Télétravail partiel
# 1           None          CDI  Télétravail occasionnel
# 2           None          CDI      Télétravail partiel
# 3           None          CDI      Télétravail partiel
# 4           None          CDI      Télétravail partiel
#
#                                           Criterions  \
# 0  [{'Domaine': 'Commun', 'Label': 'Ingénieur big...
# 1  [{'Domaine': 'Commun', 'Label': 'Ingénieur big...
# 2  [{'Domaine': 'Commun', 'Label': 'Ingénieur big...
# 3  [{'Domaine': 'Commun', 'Label': 'Ingénieur big...
# 4  [{'Domaine': 'Commun', 'Label': 'Ingénieur big...
#
#                                          Description  ... IsLowQuality  \
# 0  À ton arrivée, nous te présenterons le projet ...  ...        False
# 1  Dans le cadre de notre développement, nous rec...  ...        False
# 2  Dans un souci d'accessibilité et de clarté, le...  ...        False
# 3  Data Ingénieur(e) F/H\n\nDescription de poste\...  ...        False
# 4  En coordination avec les équipes d'un de nos c...  ...        False
#
#   IsManagement IsNonClient IsPremium  IsSalaryDisplayable  ReferencingSummary  \
# 0        False       False     False                 True                None
# 1        False       False     False                 True                None
# 2        False       False     False                False                None
# 3        False       False     False                False                None
# 4        False       False     False                False                None
#
#                                          ResponseUrl ResponseEmail  \
# 0                                               None          None
# 1                                               None          None
# 2  https://jobs.smartrecruiters.com/ASIFR/7440000...          None
# 3  https://cgi.njoyn.com/corp/xweb/xweb.asp?clid=...          None
# 4  https://alteca.nous-recrutons.fr/poste/cqr1ltt...          None
#
#   TypeResponse                                        UrlBookmark
# 0            3  /fr-fr/candidat/saveoffernewserp?idOffre=61043870
# 1            3  /fr-fr/candidat/saveoffernewserp?idOffre=60843130
# 2            3  /fr-fr/candidat/saveoffernewserp?idOffre=60680157
# 3            6  /fr-fr/candidat/saveoffernewserp?idOffre=60682934
# 4            2  /fr-fr/candidat/saveoffernewserp?idOffre=60659766
#
# [5 rows x 64 columns]

# %%
df_offres['Telework'].value_counts()
# Out:
# Telework
# Télétravail partiel        2801
# Télétravail occasionnel     668
# Télétravail complet          69
# Name: count, dtype: int64

# %%
df_offres['ContractDurationFromNumber'].value_counts()
# Out:
# ContractDurationFromNumber
# 6 mois         231
# 24 mois         76
# 1 an            38
# 2 ans           29
# 18 mois         28
# 12 mois         28
# 3 mois          25
# 4 mois          17
# 16 mois         13
# 15 mois          9
# 8 mois           6
# 5 mois           5
# 9 mois           5
# 22 jours         4
# 7 mois           2
# 3 ans            2
# 36 mois          2
# 180 jours        2
# 10 semaines      2
# 179 jours        2
# 11 mois          2
# 30 mois          1
# 44 jours         1
# 1 mois           1
# Name: count, dtype: int64

# %%
df_offres['Domaine'].value_counts()
# Out:
# Domaine
# informatique           4440
# audit                   264
# marketing               169
# ingenierie              130
# recherche               116
# commerce                 97
# finance                  83
# gestion                  67
# comptabilite             65
# production               55
# logistique               54
# industrie                47
# btp                      34
# graphisme                32
# qualite                  29
# securite                 28
# ressources-humaines      19
# banque                   15
# secretariat              14
# achat                    14
# environnement            14
# architecture             13
# telecom                  13
# immobilier               10
# edition                  10
# electronique              9
# biotechnologie            8
# administratif             8
# automobile                7
# sav                       6
# juridique                 5
# direction                 5
# sante                     5
# hotellerie                5
# chimie                    4
# hospitalier               3
# aeronautique              3
# nautisme                  2
# distribution              2
# beaute                    2
# nettoyage                 2
# defense                   2
# communication             2
# agricole                  2
# pub                       2
# audiovisuel               1
# enseignement              1
# social                    1
# Name: count, dtype: int64

# %%
df_offres['HighLights'].value_counts()
# Out:
# HighLights
# {}                                                                                                                                                       4886
# {'Description': ['de business intelligence pour se préparer aux métiers (post facture électronique) de data contrôleur&#x2F;<strong>data</strong>']}       15
# {'Profil': ['Français, Anglais
#
#           Catégories
#           <strong>Data</strong>']}                                        15
# {'Description': ['Depuis 2015, DSTI a formé + de 1000 étudiants sur les métiers de la donnée (Data Analyst&#x2F;<strong>Data Engineer</strong>']}          14
# {'Description': ['Depuis 2015, DSTI a formé + de 1000 étudiants sur les métiers de la donnée (<strong>Data Analyst</strong>&#x2F;Data Engineer']}          14
#                                                                                                                                                          ...
# {'Description': ['intervenez dans une practice à taille humaine composée de business analysts, de product owners, de <strong>data</strong>']}               1
# {'Description': ['Key Word : <strong>Data scientist</strong> - Actuaire - prévoyance individuelle - Risk - Sélection médicale - AERPI -']}                  1
# {'Description': ['· Coordonner les équipes techniques (data engineers, <strong>data scientists</strong>) pour garantir le bon déroulement']}                1
# {'Description': ['accessibles, de haute qualité et bien organisées pour répondre aux besoins des équipes d&#x27;analyse, des <strong>data</strong>']}       1
# {'Description': ['engineers back (Java, Kotlin)
# - Product managers
# - UX designers
# - Cloud engineers
# - Data engineers and <strong>data</strong>']}           1
# Name: count, Length: 639, dtype: int64

# %%
df_offres.columns
# Out:
# Index(['AddressGeoloc', 'ContractDurationFromNumber', 'ContractBeginDate',
#        'ContractEndDate', 'Shift', 'AltCompanyName', 'ContractType',
#        'Telework', 'Criterions', 'Description', 'Domaine', 'HighLights', 'Id',
#        'IdOrRef', 'IdCategory', 'IdApplication', 'LinkedOffers',
#        'Localisation', 'Localisations', 'OfferPosition', 'OfferTitle',
#        'Profile', 'PublishDate', 'RandomId', 'Ref', 'DisplayedSalary',
#        'SearchSlug', 'SkinHeaderPicture', 'SkinHeaderPictureFullUrl', 'Tags',
#        'SeoTags', 'TypeResponseFront', 'TypeListeOffres', 'Variant',
#        'UrlOffre', 'UrlSlug', 'CompanyId', 'CompanyLogo', 'CompanyLogoFullUrl',
#        'CompanyName', 'CompanyNameSlug', 'IsResponsiveRecruiter',
#        'IsAnnonceAugmentee', 'IsAnonymous', 'IsApplicationSecondaire',
#        'IsClient', 'IsClientSecondaire', 'IsClientSecondaireNonBoost',
#        'IsPartenairePrioritaire', 'IsPartenairePremium', 'IsPartenaire',
#        'IsPartenaireGroupe', 'IsFulltime', 'CompanyIsTransparentRecruiter',
#        'IsLowQuality', 'IsManagement', 'IsNonClient', 'IsPremium',
#        'IsSalaryDisplayable', 'ReferencingSummary', 'ResponseUrl',
#        'ResponseEmail', 'TypeResponse', 'UrlBookmark'],
#       dtype='object')

# %%
df_offres['Criterions'].value_counts() # à supprimer, dico des colonnes
# Out:
# Criterions
# [{'Domaine': 'Commun', 'Label': 'Ingénieur big data', 'Type': 'Metier', 'ShortUri': 'Ingenieur_big_data', 'Uri': '/Commun/Post/Ingenieur_big_data'}, {'Domaine': 'RJ', 'Label': 'Partiel', 'Type': 'Teletravail', 'ShortUri': 'Partiel', 'Uri': '/Commun/Teletravail/Partiel'}, {'Domaine': 'RJ', 'Label': 'Informatique - Systèmes d'Information', 'Type': 'Fonction', 'ShortUri': 'Informatique_syst_info', 'Uri': '/RJ/Offre/Fonct/Informatique_syst_info'}, {'Domaine': 'RJ', 'Label': 'Secteur informatique/ESN', 'Type': 'Secteur', 'ShortUri': 'Inform_SSII', 'Uri': '/RJ/Offre/Sect/Inform_SSII'}, {'Domaine': 'RJ', 'Label': 'Ingénieur/Cadre/Bac +5', 'Type': 'Niveau', 'ShortUri': 'Ingenieur_B5', 'Uri': '/RJ/Qualif/Ingenieur_B5'}, {'Domaine': 'RJ', 'Label': 'CDI', 'Type': 'Contrat', 'ShortUri': 'CDI', 'Uri': '/RJ/Contr/CDI'}, {'Domaine': 'RJ', 'Label': 'À convenir', 'Type': 'Salaire', 'ShortUri': 'A_convenir', 'Uri': '/RJ/Cand/Salaire/A_convenir'}, {'Domaine': 'RJ', 'Label': 'Informatique', 'Type': 'Sfonction', 'ShortUri': 'Informatiique', 'Uri': '/RJ/SupFonct/Informatiique'}, {'Domaine': 'SEO', 'Label': 'Informatique', 'Type': 'Domaine', 'ShortUri': 'Informatique', 'Uri': '/SEO/Domain/Informatique'}, {'Domaine': 'SEO', 'Label': 'Data engineer', 'Type': 'MetierSEO', 'ShortUri': 'MetierSEO_ea244f2e', 'Uri': '/SEO/Metiers/MetierSEO_ea244f2e'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            31
# [{'Domaine': 'Commun', 'Label': 'Analyste de données', 'Type': 'Metier', 'ShortUri': 'Analyste_donnees', 'Uri': '/Commun/Post/Analyste_donnees'}, {'Domaine': 'RJ', 'Label': 'Partiel', 'Type': 'Teletravail', 'ShortUri': 'Partiel', 'Uri': '/Commun/Teletravail/Partiel'}, {'Domaine': 'RJ', 'Label': 'Informatique - Systèmes d'Information', 'Type': 'Fonction', 'ShortUri': 'Informatique_syst_info', 'Uri': '/RJ/Offre/Fonct/Informatique_syst_info'}, {'Domaine': 'RJ', 'Label': 'Secteur informatique/ESN', 'Type': 'Secteur', 'ShortUri': 'Inform_SSII', 'Uri': '/RJ/Offre/Sect/Inform_SSII'}, {'Domaine': 'RJ', 'Label': 'Ingénieur/Cadre/Bac +5', 'Type': 'Niveau', 'ShortUri': 'Ingenieur_B5', 'Uri': '/RJ/Qualif/Ingenieur_B5'}, {'Domaine': 'RJ', 'Label': 'CDI', 'Type': 'Contrat', 'ShortUri': 'CDI', 'Uri': '/RJ/Contr/CDI'}, {'Domaine': 'RJ', 'Label': 'À convenir', 'Type': 'Salaire', 'ShortUri': 'A_convenir', 'Uri': '/RJ/Cand/Salaire/A_convenir'}, {'Domaine': 'RJ', 'Label': 'Informatique', 'Type': 'Sfonction', 'ShortUri': 'Informatiique', 'Uri': '/RJ/SupFonct/Informatiique'}, {'Domaine': 'SEO', 'Label': 'Informatique', 'Type': 'Domaine', 'ShortUri': 'Informatique', 'Uri': '/SEO/Domain/Informatique'}, {'Domaine': 'SEO', 'Label': 'Data analyst', 'Type': 'MetierSEO', 'ShortUri': 'MetierSEO_f780fdcc', 'Uri': '/SEO/Metiers/MetierSEO_f780fdcc'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                25
# [{'Domaine': 'Commun', 'Label': 'Ingénieur big data', 'Type': 'Metier', 'ShortUri': 'Ingenieur_big_data', 'Uri': '/Commun/Post/Ingenieur_big_data'}, {'Domaine': 'RJ', 'Label': 'Pas de télétravail', 'Type': 'Teletravail', 'ShortUri': 'Pas_teletravail', 'Uri': '/Commun/Teletravail/Pas_teletravail'}, {'Domaine': 'RJ', 'Label': 'Temps plein', 'Type': 'Temps_trav', 'ShortUri': 'Temps_plein', 'Uri': '/Commun/Temps_Travail/Temps_plein'}, {'Domaine': 'RJ', 'Label': 'Informatique - Systèmes d'Information', 'Type': 'Fonction', 'ShortUri': 'Informatique_syst_info', 'Uri': '/RJ/Offre/Fonct/Informatique_syst_info'}, {'Domaine': 'RJ', 'Label': 'Secteur informatique/ESN', 'Type': 'Secteur', 'ShortUri': 'Inform_SSII', 'Uri': '/RJ/Offre/Sect/Inform_SSII'}, {'Domaine': 'RJ', 'Label': '+ 7 ans', 'Type': 'Experience', 'ShortUri': 'Sup_7', 'Uri': '/RJ/Offre/Exp/Sup_7'}, {'Domaine': 'RJ', 'Label': 'Ingénieur/Cadre/Bac +5', 'Type': 'Niveau', 'ShortUri': 'Ingenieur_B5', 'Uri': '/RJ/Qualif/Ingenieur_B5'}, {'Domaine': 'RJ', 'Label': 'CDI', 'Type': 'Contrat', 'ShortUri': 'CDI', 'Uri': '/RJ/Contr/CDI'}, {'Domaine': 'RJ', 'Label': 'À convenir', 'Type': 'Salaire', 'ShortUri': 'A_convenir', 'Uri': '/RJ/Cand/Salaire/A_convenir'}, {'Domaine': 'RJ', 'Label': 'Informatique', 'Type': 'Sfonction', 'ShortUri': 'Informatiique', 'Uri': '/RJ/SupFonct/Informatiique'}, {'Domaine': 'SEO', 'Label': 'Informatique', 'Type': 'Domaine', 'ShortUri': 'Informatique', 'Uri': '/SEO/Domain/Informatique'}, {'Domaine': 'SEO', 'Label': 'Data engineer', 'Type': 'MetierSEO', 'ShortUri': 'MetierSEO_ea244f2e', 'Uri': '/SEO/Metiers/MetierSEO_ea244f2e'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         21
# [{'Domaine': 'Commun', 'Label': 'Ingénieur en systèmes d'information', 'Type': 'Metier', 'ShortUri': 'Ingenieur_syst_info', 'Uri': '/Commun/Post/Ingenieur_syst_info'}, {'Domaine': 'Commun', 'Label': 'Système d'information', 'Type': 'Competence', 'ShortUri': 'Management_systeme_info', 'Uri': '/Commun/Comp/Management_systeme_info'}, {'Domaine': 'RJ', 'Label': 'Complet', 'Type': 'Teletravail', 'ShortUri': 'Complet', 'Uri': '/Commun/Teletravail/Complet'}, {'Domaine': 'RJ', 'Label': 'Temps plein', 'Type': 'Temps_trav', 'ShortUri': 'Temps_plein', 'Uri': '/Commun/Temps_Travail/Temps_plein'}, {'Domaine': 'RJ', 'Label': 'Informatique - Systèmes d'Information', 'Type': 'Fonction', 'ShortUri': 'Informatique_syst_info', 'Uri': '/RJ/Offre/Fonct/Informatique_syst_info'}, {'Domaine': 'RJ', 'Label': 'Secteur informatique/ESN', 'Type': 'Secteur', 'ShortUri': 'Inform_SSII', 'Uri': '/RJ/Offre/Sect/Inform_SSII'}, {'Domaine': 'RJ', 'Label': '1 à 7 ans', 'Type': 'Experience', 'ShortUri': '1_7', 'Uri': '/RJ/Offre/Exp/1_7'}, {'Domaine': 'RJ', 'Label': 'Agent de maîtrise/Bac +3/4', 'Type': 'Niveau', 'ShortUri': 'Agent_maitrise_B3', 'Uri': '/RJ/Qualif/Agent_maitrise_B3'}, {'Domaine': 'RJ', 'Label': 'Ingénieur/Cadre/Bac +5', 'Type': 'Niveau', 'ShortUri': 'Ingenieur_B5', 'Uri': '/RJ/Qualif/Ingenieur_B5'}, {'Domaine': 'RJ', 'Label': 'Alternance', 'Type': 'Contrat', 'ShortUri': 'Alternance', 'Uri': '/RJ/Contr/Alternance'}, {'Domaine': 'RJ', 'Label': '20 à 25 kE', 'Type': 'Salaire', 'ShortUri': '20_25', 'Uri': '/RJ/Cand/Salaire/20_25'}, {'Domaine': 'RJ', 'Label': '15 à 20 kE', 'Type': 'Salaire', 'ShortUri': '15_20', 'Uri': '/RJ/Cand/Salaire/15_20'}, {'Domaine': 'RJ', 'Label': '- 15 kE', 'Type': 'Salaire', 'ShortUri': 'Inf_15', 'Uri': '/RJ/Cand/Salaire/Inf_15'}, {'Domaine': 'RJ', 'Label': 'Informatique', 'Type': 'Sfonction', 'ShortUri': 'Informatiique', 'Uri': '/RJ/SupFonct/Informatiique'}, {'Domaine': 'SEO', 'Label': 'Informatique', 'Type': 'Domaine', 'ShortUri': 'Informatique', 'Uri': '/SEO/Domain/Informatique'}, {'Domaine': 'SEO', 'Label': 'Ingénieur en systèmes d'information', 'Type': 'MetierSEO', 'ShortUri': 'MetierSEO_89d8e3ff', 'Uri': '/SEO/Metiers/MetierSEO_89d8e3ff'}]    17
# [{'Domaine': 'Commun', 'Label': 'Ingénieur big data', 'Type': 'Metier', 'ShortUri': 'Ingenieur_big_data', 'Uri': '/Commun/Post/Ingenieur_big_data'}, {'Domaine': 'Commun', 'Label': 'Langages de programmation', 'Type': 'Competence', 'ShortUri': 'Langages_programmation', 'Uri': '/Commun/Comp/Langages_programmation'}, {'Domaine': 'RJ', 'Label': 'Partiel', 'Type': 'Teletravail', 'ShortUri': 'Partiel', 'Uri': '/Commun/Teletravail/Partiel'}, {'Domaine': 'RJ', 'Label': 'Informatique - Systèmes d'Information', 'Type': 'Fonction', 'ShortUri': 'Informatique_syst_info', 'Uri': '/RJ/Offre/Fonct/Informatique_syst_info'}, {'Domaine': 'RJ', 'Label': 'Services aux Entreprises', 'Type': 'Secteur', 'ShortUri': 'Serv_entreprise', 'Uri': '/RJ/Offre/Sect/Serv_entreprise'}, {'Domaine': 'RJ', 'Label': 'Ingénieur/Cadre/Bac +5', 'Type': 'Niveau', 'ShortUri': 'Ingenieur_B5', 'Uri': '/RJ/Qualif/Ingenieur_B5'}, {'Domaine': 'RJ', 'Label': 'CDI', 'Type': 'Contrat', 'ShortUri': 'CDI', 'Uri': '/RJ/Contr/CDI'}, {'Domaine': 'RJ', 'Label': 'À convenir', 'Type': 'Salaire', 'ShortUri': 'A_convenir', 'Uri': '/RJ/Cand/Salaire/A_convenir'}, {'Domaine': 'RJ', 'Label': 'Informatique', 'Type': 'Sfonction', 'ShortUri': 'Informatiique', 'Uri': '/RJ/SupFonct/Informatiique'}, {'Domaine': 'SEO', 'Label': 'Informatique', 'Type': 'Domaine', 'ShortUri': 'Informatique', 'Uri': '/SEO/Domain/Informatique'}, {'Domaine': 'SEO', 'Label': 'Data engineer', 'Type': 'MetierSEO', 'ShortUri': 'MetierSEO_ea244f2e', 'Uri': '/SEO/Metiers/MetierSEO_ea244f2e'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             15
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ..
# [{'Domaine': 'Commun', 'Label': 'Consultant en organisation', 'Type': 'Metier', 'ShortUri': 'Consultant_organisation', 'Uri': '/Commun/Post/Consultant_organisation'}, {'Domaine': 'Commun', 'Label': 'Conduite du changement', 'Type': 'Competence', 'ShortUri': 'Conduite_changement', 'Uri': '/Commun/Comp/Conduite_changement'}, {'Domaine': 'RJ', 'Label': 'Partiel', 'Type': 'Teletravail', 'ShortUri': 'Partiel', 'Uri': '/Commun/Teletravail/Partiel'}, {'Domaine': 'RJ', 'Label': 'Bureau d'Etudes/R&D/BTP archi/conception', 'Type': 'Fonction', 'ShortUri': 'Bureau_etude_R_D', 'Uri': '/RJ/Offre/Fonct/Bureau_etude_R_D'}, {'Domaine': 'RJ', 'Label': 'Secteur informatique/ESN', 'Type': 'Secteur', 'ShortUri': 'Inform_SSII', 'Uri': '/RJ/Offre/Sect/Inform_SSII'}, {'Domaine': 'RJ', 'Label': '+ 7 ans', 'Type': 'Experience', 'ShortUri': 'Sup_7', 'Uri': '/RJ/Offre/Exp/Sup_7'}, {'Domaine': 'RJ', 'Label': 'Ingénieur/Cadre/Bac +5', 'Type': 'Niveau', 'ShortUri': 'Ingenieur_B5', 'Uri': '/RJ/Qualif/Ingenieur_B5'}, {'Domaine': 'RJ', 'Label': 'CDI', 'Type': 'Contrat', 'ShortUri': 'CDI', 'Uri': '/RJ/Contr/CDI'}, {'Domaine': 'RJ', 'Label': 'À convenir', 'Type': 'Salaire', 'ShortUri': 'A_convenir', 'Uri': '/RJ/Cand/Salaire/A_convenir'}, {'Domaine': 'RJ', 'Label': 'BTP/Bureau d'études', 'Type': 'Sfonction', 'ShortUri': 'BTP_BE', 'Uri': '/RJ/SupFonct/BTP_BE'}, {'Domaine': 'SEO', 'Label': 'Gestion', 'Type': 'Domaine', 'ShortUri': 'Gestion', 'Uri': '/SEO/Domain/Gestion'}, {'Domaine': 'SEO', 'Label': 'Consultant en organisation', 'Type': 'MetierSEO', 'ShortUri': 'MetierSEO_1cadaeae', 'Uri': '/SEO/Metiers/MetierSEO_1cadaeae'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [{'Domaine': 'Commun', 'Label': 'Développeur informatique', 'Type': 'Metier', 'ShortUri': 'Developpeur', 'Uri': '/Commun/Post/Developpeur'}, {'Domaine': 'Commun', 'Label': 'Esprit d'analyse', 'Type': 'Competence', 'ShortUri': 'Analyse', 'Uri': '/Commun/Comp/Analyse'}, {'Domaine': 'RJ', 'Label': 'Partiel', 'Type': 'Teletravail', 'ShortUri': 'Partiel', 'Uri': '/Commun/Teletravail/Partiel'}, {'Domaine': 'RJ', 'Label': 'Informatique - Développement', 'Type': 'Fonction', 'ShortUri': 'Informatique_dev', 'Uri': '/RJ/Offre/Fonct/Informatique_dev'}, {'Domaine': 'RJ', 'Label': 'Banque/Assurance/Finance', 'Type': 'Secteur', 'ShortUri': 'Banq_assur_finan', 'Uri': '/RJ/Offre/Sect/Banq_assur_finan'}, {'Domaine': 'RJ', 'Label': 'Technicien/Employé Bac +2', 'Type': 'Niveau', 'ShortUri': 'Technicien_B2', 'Uri': '/RJ/Qualif/Technicien_B2'}, {'Domaine': 'RJ', 'Label': 'Agent de maîtrise/Bac +3/4', 'Type': 'Niveau', 'ShortUri': 'Agent_maitrise_B3', 'Uri': '/RJ/Qualif/Agent_maitrise_B3'}, {'Domaine': 'RJ', 'Label': 'Ingénieur/Cadre/Bac +5', 'Type': 'Niveau', 'ShortUri': 'Ingenieur_B5', 'Uri': '/RJ/Qualif/Ingenieur_B5'}, {'Domaine': 'RJ', 'Label': 'CDI', 'Type': 'Contrat', 'ShortUri': 'CDI', 'Uri': '/RJ/Contr/CDI'}, {'Domaine': 'RJ', 'Label': '35 à 40 kE', 'Type': 'Salaire', 'ShortUri': '35_40', 'Uri': '/RJ/Cand/Salaire/35_40'}, {'Domaine': 'RJ', 'Label': '45 à 50 kE', 'Type': 'Salaire', 'ShortUri': '45_50', 'Uri': '/RJ/Cand/Salaire/45_50'}, {'Domaine': 'RJ', 'Label': '40 à 45 kE', 'Type': 'Salaire', 'ShortUri': '40_45', 'Uri': '/RJ/Cand/Salaire/40_45'}, {'Domaine': 'RJ', 'Label': 'Informatique', 'Type': 'Sfonction', 'ShortUri': 'Informatiique', 'Uri': '/RJ/SupFonct/Informatiique'}, {'Domaine': 'SEO', 'Label': 'Informatique', 'Type': 'Domaine', 'ShortUri': 'Informatique', 'Uri': '/SEO/Domain/Informatique'}, {'Domaine': 'SEO', 'Label': 'Analyste développeur', 'Type': 'MetierSEO', 'ShortUri': 'MetierSEO_36025dfb', 'Uri': '/SEO/Metiers/MetierSEO_36025dfb'}]                                                                                                                                                                                                                              1
# [{'Domaine': 'Commun', 'Label': 'Responsable du contrôle de gestion', 'Type': 'Metier', 'ShortUri': 'Responsable_controle_gestion', 'Uri': '/Commun/Post/Responsable_controle_gestion'}, {'Domaine': 'RJ', 'Label': 'Temps plein', 'Type': 'Temps_trav', 'ShortUri': 'Temps_plein', 'Uri': '/Commun/Temps_Travail/Temps_plein'}, {'Domaine': 'RJ', 'Label': 'Compta/Gestion/Finance/Audit', 'Type': 'Fonction', 'ShortUri': 'Compta_gestion_finance_audit', 'Uri': '/RJ/Offre/Fonct/Compta_gestion_finance_audit'}, {'Domaine': 'RJ', 'Label': 'Industrie Manufacturière', 'Type': 'Secteur', 'ShortUri': 'Ind_manufact', 'Uri': '/RJ/Offre/Sect/Ind_manufact'}, {'Domaine': 'RJ', 'Label': '1 à 7 ans', 'Type': 'Experience', 'ShortUri': '1_7', 'Uri': '/RJ/Offre/Exp/1_7'}, {'Domaine': 'RJ', 'Label': 'Ingénieur/Cadre/Bac +5', 'Type': 'Niveau', 'ShortUri': 'Ingenieur_B5', 'Uri': '/RJ/Qualif/Ingenieur_B5'}, {'Domaine': 'RJ', 'Label': 'CDI', 'Type': 'Contrat', 'ShortUri': 'CDI', 'Uri': '/RJ/Contr/CDI'}, {'Domaine': 'RJ', 'Label': '35 à 40 kE', 'Type': 'Salaire', 'ShortUri': '35_40', 'Uri': '/RJ/Cand/Salaire/35_40'}, {'Domaine': 'RJ', 'Label': '45 à 50 kE', 'Type': 'Salaire', 'ShortUri': '45_50', 'Uri': '/RJ/Cand/Salaire/45_50'}, {'Domaine': 'RJ', 'Label': '40 à 45 kE', 'Type': 'Salaire', 'ShortUri': '40_45', 'Uri': '/RJ/Cand/Salaire/40_45'}, {'Domaine': 'RJ', 'Label': 'Administration', 'Type': 'Sfonction', 'ShortUri': 'Administration', 'Uri': '/RJ/SupFonct/Administration'}, {'Domaine': 'SEO', 'Label': 'Gestion', 'Type': 'Domaine', 'ShortUri': 'Gestion', 'Uri': '/SEO/Domain/Gestion'}, {'Domaine': 'SEO', 'Label': 'Responsable de gestion', 'Type': 'MetierSEO', 'ShortUri': 'MetierSEO_6928bf1e', 'Uri': '/SEO/Metiers/MetierSEO_6928bf1e'}, {'Domaine': 'RJ', 'Label': 'Pas de télétravail', 'Type': 'Teletravail', 'ShortUri': 'Pas_teletravail', 'Uri': 'http://www.rj.com/Commun/Teletravail/Pas_teletravail'}]                                                                                                                                                                                                                                                                                                        1
# [{'Domaine': 'Commun', 'Label': 'Ingénieur IT infrastructure', 'Type': 'Metier', 'ShortUri': 'Ingenieur_IT_infrastructure', 'Uri': '/Commun/Post/Ingenieur_IT_infrastructure'}, {'Domaine': 'RJ', 'Label': 'Partiel', 'Type': 'Teletravail', 'ShortUri': 'Partiel', 'Uri': '/Commun/Teletravail/Partiel'}, {'Domaine': 'RJ', 'Label': 'Informatique - Systèmes/Réseaux', 'Type': 'Fonction', 'ShortUri': 'Informatique_syst_reseaux', 'Uri': '/RJ/Offre/Fonct/Informatique_syst_reseaux'}, {'Domaine': 'RJ', 'Label': 'Services aux Entreprises', 'Type': 'Secteur', 'ShortUri': 'Serv_entreprise', 'Uri': '/RJ/Offre/Sect/Serv_entreprise'}, {'Domaine': 'RJ', 'Label': 'Ingénieur/Cadre/Bac +5', 'Type': 'Niveau', 'ShortUri': 'Ingenieur_B5', 'Uri': '/RJ/Qualif/Ingenieur_B5'}, {'Domaine': 'RJ', 'Label': 'CDI', 'Type': 'Contrat', 'ShortUri': 'CDI', 'Uri': '/RJ/Contr/CDI'}, {'Domaine': 'RJ', 'Label': 'À convenir', 'Type': 'Salaire', 'ShortUri': 'A_convenir', 'Uri': '/RJ/Cand/Salaire/A_convenir'}, {'Domaine': 'RJ', 'Label': 'Informatique', 'Type': 'Sfonction', 'ShortUri': 'Informatiique', 'Uri': '/RJ/SupFonct/Informatiique'}, {'Domaine': 'SEO', 'Label': 'Informatique', 'Type': 'Domaine', 'ShortUri': 'Informatique', 'Uri': '/SEO/Domain/Informatique'}, {'Domaine': 'SEO', 'Label': 'Architecte infrastructure', 'Type': 'MetierSEO', 'ShortUri': 'MetierSEO_41d3e57a', 'Uri': '/SEO/Metiers/MetierSEO_41d3e57a'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{'Domaine': 'Commun', 'Label': 'Infographiste', 'Type': 'Metier', 'ShortUri': 'Infographiste', 'Uri': '/Commun/Post/Infographiste'}, {'Domaine': 'Commun', 'Label': 'Créativité', 'Type': 'Competence', 'ShortUri': 'Creativite', 'Uri': '/Commun/Comp/Creativite'}, {'Domaine': 'RJ', 'Label': 'Partiel', 'Type': 'Teletravail', 'ShortUri': 'Partiel', 'Uri': '/Commun/Teletravail/Partiel'}, {'Domaine': 'RJ', 'Label': 'Temps plein', 'Type': 'Temps_trav', 'ShortUri': 'Temps_plein', 'Uri': '/Commun/Temps_Travail/Temps_plein'}, {'Domaine': 'RJ', 'Label': 'Marketing/Communication/Graphisme', 'Type': 'Fonction', 'ShortUri': 'Marketing_com_graphisme', 'Uri': '/RJ/Offre/Fonct/Marketing_com_graphisme'}, {'Domaine': 'RJ', 'Label': 'Secteur informatique/ESN', 'Type': 'Secteur', 'ShortUri': 'Inform_SSII', 'Uri': '/RJ/Offre/Sect/Inform_SSII'}, {'Domaine': 'RJ', 'Label': 'Technicien/Employé Bac +2', 'Type': 'Niveau', 'ShortUri': 'Technicien_B2', 'Uri': '/RJ/Qualif/Technicien_B2'}, {'Domaine': 'RJ', 'Label': 'Agent de maîtrise/Bac +3/4', 'Type': 'Niveau', 'ShortUri': 'Agent_maitrise_B3', 'Uri': '/RJ/Qualif/Agent_maitrise_B3'}, {'Domaine': 'RJ', 'Label': 'CDI', 'Type': 'Contrat', 'ShortUri': 'CDI', 'Uri': '/RJ/Contr/CDI'}, {'Domaine': 'RJ', 'Label': 'À convenir', 'Type': 'Salaire', 'ShortUri': 'A_convenir', 'Uri': '/RJ/Cand/Salaire/A_convenir'}, {'Domaine': 'RJ', 'Label': 'Marketing/Communication/Graphisme', 'Type': 'Sfonction', 'ShortUri': 'Market_Com_Graph', 'Uri': '/RJ/SupFonct/Market_Com_Graph'}, {'Domaine': 'SEO', 'Label': 'Graphisme', 'Type': 'Domaine', 'ShortUri': 'Graphisme', 'Uri': '/SEO/Domain/Graphisme'}, {'Domaine': 'SEO', 'Label': 'Product designer', 'Type': 'MetierSEO', 'ShortUri': 'MetierSEO_aa282c46', 'Uri': '/SEO/Metiers/MetierSEO_aa282c46'}]                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Name: count, Length: 3191, dtype: int64

# %%
df_offres['ContractType'].value_counts()
# Out:
# ContractType
# CDI                      4705
# Stage                     773
# Alternance                288
# Indépendant/Freelance     144
# CDD                       132
# Intérim                    71
# Franchise                   2
# Name: count, dtype: int64

# %% [markdown]
# ## **6. Nettoyage des données**

# %%
# suppression des colonnes inutiles
df_offres = df_offres.drop(columns=['AddressGeoloc', 'ContractBeginDate', 'ContractEndDate', 'Shift', 
                                    'AltCompanyName'])

# %% [markdown]
# ## **7. Sauvegarde des données**

# %%
# Exportation des données nettoyées au format CSV.
output_file = "../data/datasets/brut/offres_data_engineer.csv"
df_clean.to_csv(output_file, index=False)
print(f"Données sauvegardées dans le fichier {output_file}.")
